# %% [markdown]
# # PROCESS MAPPING V8 → V12

# %% [markdown]
# ## Installer les librairies nécessaires

# %%
import pandas as pd
# Afficher le DataFrame sans limitation en largeur
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', None)

import json
import re
import sqlglot
import pyodbc
import csv
import xml.etree.ElementTree as ET

# %% [markdown]
# ## Exploiter l'EOM Sage V12

# %% [markdown]
# >Ce fichier utilise des données provenant de Sage X3 - V12
# >- Utilisation de l'EOM V12 et notamment :
# >    - Table Principale
# >    - Tables Liées
# >    - Zones Parametrées

# %%
# Fichier EOM Sage V8-V12
eom_file = r".\data\Mapping_from_EOM_ZoneParamV12.xlsx"

# %%
from openpyxl import load_workbook

# Charger le fichier Excel et lire l'onglet "Mapping_V8V12" du fichier "Mapping_from_EOM_ZoneParamV12.xlsx" avec openpyxl
wb = load_workbook(filename=eom_file, data_only=True)
sheet = wb['Mapping_V8V12']

# Lire les données de la feuille et les convertir en dataframe
data = sheet.values
columns = next(data)[0:]
df_eom_raw = pd.DataFrame(data, columns=columns)

# Sélectionner les colonnes d'intérêt et les renommer
df_eom = df_eom_raw[['TableChamp_V8', 'TableChamp_V12', 'Désignation_MyReport']].rename(columns={
    'TableChamp_V8': 'tablechamp_v8',
    'TableChamp_V12': 'tablechamp_v12',
    'Désignation_MyReport': 'designation_champ_sortie'
})

# Ne selectionner que les lignes valides du mapping, celles dont la valeur est différente de 0
df_eom = df_eom[df_eom["tablechamp_v12"]!=0].reset_index(drop=True)

print(df_eom .info())
df_eom.head(18)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 3 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   tablechamp_v8             63 non-null     object
#  1   tablechamp_v12            63 non-null     object
#  2   designation_champ_sortie  63 non-null     object
# dtypes: object(3)
# memory usage: 1.6+ KB
# None
#            tablechamp_v8           tablechamp_v12            designation_champ_sortie
# 0       MACHINEFL.MACNUM      XRMWMACPAR00.MACNUM                    Wag_Code Machine
# 1       MACHINEFL.MACTYP      XRMWMACPAR00.MACTYP         Wag_Code Catégorie de wagon
# 2        MACHINES.SALFCY      XRMWMACPAR00.SALFCY                      Wag_PC Origine
# 3       MACHINEFL.SERNUM      XRMWMACPAR00.SERNUM                         N° de série
# 4          YTECSPE1.XAIO          XRMW1TSP01.XAIO   Wag_Aptitude à l'interopérabilité
# 5          YPARCWAG.XLOG        XRMWMACMIL01.XLOG                 Wag_code retour PMA
# 6          YPARCWAG.XPMA        XRMWMACMIL01.XPMA           Wag_Parcours moyen annuel
# 7       YPARCWAG.YBPCUSR        XRMWCONMAC.BPCUSR         Wag_Code client utilisateur
# 8       YPARCWAG.YCONREV        XRMWCONMAC.CONREV                 Wag_contrat avenant
# 9   YPARCWAG.YDATNEXTREV  WXRMWPRGDAT.DATENEXTREV  Wag_Prochaine opération périodique
# 10      YMAINPLAN.YMPLIB           XRMWMPL.YMPLIB         Libellé Plan de maintenance
# 11     MACHINEFL.YPLNMCE           XRMWMPL.YMPNUM                 N° Plan maintenance
# 12       MACHINEFL.YSA01       XRMWMACIMM00.YHI00              Wag_N° Immatriculation
# 13       MACHINEFL.YSA04       XRMWMACPAR01.YSA04               Wag_Pool mat (gérant)
# 14       MACHINEFL.YSA09       XRMWMACPAR01.YSA09                Wag_Etat du matériel
# 15       MACHINEFL.YSA41       XRMWMACPAR01.YSA41                Wag_Code Pool Essieu
# 16       MACHINEFL.YSG01       XRMWMACPAR01.YSG01          Wag_Date d'entrée sur parc
# 17       MACHINEFL.YSG02       XRMWMACPAR01.YSG02         Wag_Date désimmatriculation

# %%
df_eom['table_v8'] = df_eom['tablechamp_v8'].str.split('.').str[0]
df_eom['champ_v8'] = df_eom['tablechamp_v8'].str.split('.').str[1]
df_eom['table_v12'] = df_eom['tablechamp_v12'].str.split('.').str[0]
df_eom['champ_v12'] = df_eom['tablechamp_v12'].str.split('.').str[1]
df_eom = df_eom[['designation_champ_sortie','tablechamp_v8','table_v8','champ_v8','tablechamp_v12','table_v12','champ_v12']]

# %%
df_eom
# Out:
#                     designation_champ_sortie         tablechamp_v8   table_v8     champ_v8           tablechamp_v12     table_v12    champ_v12
# 0                           Wag_Code Machine      MACHINEFL.MACNUM  MACHINEFL       MACNUM      XRMWMACPAR00.MACNUM  XRMWMACPAR00       MACNUM
# 1                Wag_Code Catégorie de wagon      MACHINEFL.MACTYP  MACHINEFL       MACTYP      XRMWMACPAR00.MACTYP  XRMWMACPAR00       MACTYP
# 2                             Wag_PC Origine       MACHINES.SALFCY   MACHINES       SALFCY      XRMWMACPAR00.SALFCY  XRMWMACPAR00       SALFCY
# 3                                N° de série      MACHINEFL.SERNUM  MACHINEFL       SERNUM      XRMWMACPAR00.SERNUM  XRMWMACPAR00       SERNUM
# 4          Wag_Aptitude à l'interopérabilité         YTECSPE1.XAIO   YTECSPE1         XAIO          XRMW1TSP01.XAIO    XRMW1TSP01         XAIO
# 5                        Wag_code retour PMA         YPARCWAG.XLOG   YPARCWAG         XLOG        XRMWMACMIL01.XLOG  XRMWMACMIL01         XLOG
# 6                  Wag_Parcours moyen annuel         YPARCWAG.XPMA   YPARCWAG         XPMA        XRMWMACMIL01.XPMA  XRMWMACMIL01         XPMA
# 7                Wag_Code client utilisateur      YPARCWAG.YBPCUSR   YPARCWAG      YBPCUSR        XRMWCONMAC.BPCUSR    XRMWCONMAC       BPCUSR
# 8                        Wag_contrat avenant      YPARCWAG.YCONREV   YPARCWAG      YCONREV        XRMWCONMAC.CONREV    XRMWCONMAC       CONREV
# 9         Wag_Prochaine opération périodique  YPARCWAG.YDATNEXTREV   YPARCWAG  YDATNEXTREV  WXRMWPRGDAT.DATENEXTREV   WXRMWPRGDAT  DATENEXTREV
# 10               Libellé Plan de maintenance      YMAINPLAN.YMPLIB  YMAINPLAN       YMPLIB           XRMWMPL.YMPLIB       XRMWMPL       YMPLIB
# 11                       N° Plan maintenance     MACHINEFL.YPLNMCE  MACHINEFL      YPLNMCE           XRMWMPL.YMPNUM       XRMWMPL       YMPNUM
# 12                    Wag_N° Immatriculation       MACHINEFL.YSA01  MACHINEFL        YSA01       XRMWMACIMM00.YHI00  XRMWMACIMM00        YHI00
# 13                     Wag_Pool mat (gérant)       MACHINEFL.YSA04  MACHINEFL        YSA04       XRMWMACPAR01.YSA04  XRMWMACPAR01        YSA04
# 14                      Wag_Etat du matériel       MACHINEFL.YSA09  MACHINEFL        YSA09       XRMWMACPAR01.YSA09  XRMWMACPAR01        YSA09
# 15                      Wag_Code Pool Essieu       MACHINEFL.YSA41  MACHINEFL        YSA41       XRMWMACPAR01.YSA41  XRMWMACPAR01        YSA41
# 16                Wag_Date d'entrée sur parc       MACHINEFL.YSG01  MACHINEFL        YSG01       XRMWMACPAR01.YSG01  XRMWMACPAR01        YSG01
# 17               Wag_Date désimmatriculation       MACHINEFL.YSG02  MACHINEFL        YSG02       XRMWMACPAR01.YSG02  XRMWMACPAR01        YSG02
# 18                            Wag_Mandataire       MACHINEFL.YSG04  MACHINEFL        YSG04       XRMWMACPAR01.YSG04  XRMWMACPAR01        YSG04
# 19                          Wag_Gestionnaire       MACHINEFL.YSG05  MACHINEFL        YSG05       XRMWMACPAR01.YSG05  XRMWMACPAR01        YSG05
# 20                    Wag_Détenteur immatric       MACHINEFL.YSG06  MACHINEFL        YSG06       XRMWMACPAR01.YSG06  XRMWMACPAR01        YSG06
# 21             Wag_Code Exploitant technique       MACHINEFL.YSG07  MACHINEFL        YSG07       XRMWMACPAR01.YSG07  XRMWMACPAR01        YSG07
# 22            Wag_Code Exploitant commercial       MACHINEFL.YSG08  MACHINEFL        YSG08       XRMWMACPAR01.YSG08  XRMWMACPAR01        YSG08
# 23          Wag_Suivi investissement (CAPEX)       MACHINEFL.YSG17  MACHINEFL        YSG17       XRMWMACPAR01.YSG17  XRMWMACPAR01        YSG17
# 24                       Wag_Etat commercial        YPARCWAG.YSG28   YPARCWAG        YSG28       WXRMWMACXON0.YSG28  WXRMWMACXON0        YSG28
# 25                                   Wag_ECM       MACHINEFL.YSG33  MACHINEFL        YSG33       XRMWMACPAR01.YSG33  XRMWMACPAR01        YSG33
# 26                           Wag_Code Statut     YPARCWAG.YSTATITM   YPARCWAG     YSTATITM     XRMWMACPAR04.STATITM  XRMWMACPAR04      STATITM
# 27                      Wag_Ref Construction       MACHINEFL.YTA02  MACHINEFL        YTA02       XRMWMACPAR01.YTA02  XRMWMACPAR01        YTA02
# 28                    Wag_Code Type de Wagon       MACHINEFL.YTA03  MACHINEFL        YTA03       XRMWMACPAR01.YTA03  XRMWMACPAR01        YTA03
# 29                        Date 1ère immatric       MACHINEFL.YTA05  MACHINEFL        YTA05       XRMWMACPAR01.YTA05  XRMWMACPAR01        YTA05
# 30                     Wag_Code Constructeur       MACHINEFL.YTA08  MACHINEFL        YTA08       XRMWMACPAR01.YTA08  XRMWMACPAR01        YTA08
# 31                                  Wag_Tare       YTECSPE1.YTA16I   YTECSPE1       YTA16I         XRMW1TSP01.YTA16    XRMW1TSP01        YTA16
# 32                    Wag_Longueur hors tout        YTECSPE1.YTA42   YTECSPE1        YTA42         XRMW1TSP01.YTA42    XRMW1TSP01        YTA42
# 33                    Wag_Longueur de pesage        YTECSPE1.YTA43   YTECSPE1        YTA43         XRMW1TSP01.YTA43    XRMW1TSP01        YTA43
# 34                   Wag_Empattement châssis        YTECSPE1.YTA44   YTECSPE1        YTA44         XRMW1TSP01.YTA44    XRMW1TSP01        YTA44
# 35                    Wag_Inscription courbe        YTECSPE1.YTA45   YTECSPE1        YTA45         XRMW1TSP01.YTA45    XRMW1TSP01        YTA45
# 36                    Wag_Code Type de bogie        YTECSPE1.YTA47   YTECSPE1        YTA47         XRMW1TSP03.YTA47    XRMW1TSP03        YTA47
# 37                       Wag_Code Suspension        YTECSPE1.YTA48   YTECSPE1        YTA48         XRMW1TSP08.YTA48    XRMW1TSP08        YTA48
# 38                     Wag_Décal axe citerne        YTECSPE1.YTA55   YTECSPE1        YTA55         XRMW1TSP02.YTA55    XRMW1TSP02        YTA55
# 39                     Wag_Empattement bogie        YTECSPE1.YTA56   YTECSPE1        YTA56             YATABDIV.NO1      YATABDIV          NO1
# 40             Wag_Code Type de frein à main        YTECSPE1.YTA61   YTECSPE1        YTA61         XRMW1TSP02.YTA61    XRMW1TSP02        YTA61
# 41             Wag_Code Type de distributeur        YTECSPE1.YTA62   YTECSPE1        YTA62         XRMW1TSP02.YTA62    XRMW1TSP02        YTA62
# 42                      Wag_Code Vide charge        YTECSPE1.YTA64   YTECSPE1        YTA64         XRMW1TSP02.YTA64    XRMW1TSP02        YTA64
# 43       Wag_Code Configuration des semelles       YTECSPE1.YTA67A   YTECSPE1       YTA67A        XRMW1TSP02.YTA67A    XRMW1TSP02       YTA67A
# 44                 Wag_Code Type de semelle        YTECSPE1.YTA67B   YTECSPE1       YTA67B        XRMW1TSP02.YTA67B    XRMW1TSP02       YTA67B
# 45                  Wag_Masse freinée à vide        YTECSPE1.YTA70   YTECSPE1        YTA70         XRMW1TSP02.YTA70    XRMW1TSP02        YTA70
# 46               Wag_Masse freinée en charge        YTECSPE1.YTA71   YTECSPE1        YTA71         XRMW1TSP02.YTA71    XRMW1TSP02        YTA71
# 47    Wag_Masse freinée changement de régime        YTECSPE1.YTA72   YTECSPE1        YTA72         XRMW1TSP02.YTA72    XRMW1TSP02        YTA72
# 48                       Wag_N° Distributeur        YTECSPE1.YTA73   YTECSPE1        YTA73         XRMW1TSP02.YTA73    XRMW1TSP02        YTA73
# 49     Wag_Masse freinée du frein à main (t)        YTECSPE1.YTA74   YTECSPE1        YTA74         XRMW1TSP02.YTA74    XRMW1TSP02        YTA74
# 50                Wag_Effort de retenue (Kn)        YTECSPE1.YTA75   YTECSPE1        YTA75         XRMW1TSP02.YTA75    XRMW1TSP02        YTA75
# 51                      Wag_Code Valve pesée        YTECSPE1.YTA78   YTECSPE1        YTA78         XRMW1TSP02.YTA78    XRMW1TSP02        YTA78
# 52            Wag_N° Distributeur secondaire        YTECSPE1.YTB40   YTECSPE1        YTB40         XRMW1TSP02.YTB40    XRMW1TSP02        YTB40
# 53                              Wag_Code RID        YTECSPE1.YTL01   YTECSPE1        YTL01         XRMW1TSP01.YTL01    XRMW1TSP01        YTL01
# 54                     Wag_Marquage littéral        YTECSPE1.YTL05   YTECSPE1        YTL05         XRMW1TSP01.YTL05    XRMW1TSP01        YTL05
# 55  Wag_Code Type de distributeur secondaire        YTECSPE1.YTL14   YTECSPE1        YTL14         XRMW1TSP02.YTL14    XRMW1TSP02        YTL14
# 56                               Wag_Gabarit        YTECSPE1.YTL15   YTECSPE1        YTL15         XRMW1TSP01.YTL15    XRMW1TSP01        YTL15
# 57            Wag_Date revision distributeur        YTECSPE1.YTL18   YTECSPE1        YTL18         XRMW1TSP02.YTL18    XRMW1TSP02        YTL18
# 58                     Wag_Catég Commerciale    MACHINEFL.ZCATCOMM  MACHINEFL     ZCATCOMM     XRMWMACPAR02.CATCOMM  XRMWMACPAR02      CATCOMM
# 59                         Wag_Catég gestion    MACHINEFL.ZCATGEST  MACHINEFL     ZCATGEST     XRMWMACPAR02.CATGEST  XRMWMACPAR02      CATGEST
# 60                        Wag_Code Flag RSRD    MACHINEFL.ZRSRDFLG  MACHINEFL     ZRSRDFLG    XRMWMACPAR03.ZRSRDFLG  XRMWMACPAR03     ZRSRDFLG
# 61                      Wag_Mise à jour RSRD    MACHINEFL.ZRSRDMAJ  MACHINEFL     ZRSRDMAJ    XRMWMACPAR03.ZRSRDMAJ  XRMWMACPAR03     ZRSRDMAJ
# 62                      Wag_Commentaire RSRD    MACHINEFL.ZRSRDREM  MACHINEFL     ZRSRDREM    XRMWMACPAR03.ZRSRDREM  XRMWMACPAR03     ZRSRDREM

# %%
print(f"Il y a {df_eom.shape[0]} champs de sortie de modèle à mapper")
# Out:
# Il y a 63 champs de sortie de modèle à mapper

# %% [markdown]
# ## Exploiter la Requête SQL du modèle V8

# %% [markdown]
# ### Nettoyer la Requête SQL du modèle V8 provenant de MyReport

# %%
import re
import sqlparse

# Chemins des fichiers
sql_v8_file_raw = r".\data\SQLQuery_ParcWagonV8_Raw.sql"
sql_v8_file = r".\data\SQLQuery_ParcWagonV8.sql"

# Formater la requête SQL
def format_sql_query(file_path):
    with open(file_path, 'r') as fichier:
        sql = fichier.read()
    formatted_sql = sqlparse.format(sql, reindent=True, keyword_case='upper')
    return formatted_sql

# Supprimer les alias dans la clause SELECT
def remove_aliases(sql_content):
    clause_select = re.search(r'SELECT.*?(?=FROM|WHERE|GROUP|HAVING|ORDER|LIMIT)', sql_content, re.DOTALL)
    if clause_select:
        clause_select_sans_alias = re.sub(r'AS [a-zA-Z0-9]+_\d+_\d+', '', clause_select.group())
        sql_content = sql_content.replace(clause_select.group(), clause_select_sans_alias)
    return sql_content

# Supprimer les espaces après les guillemets doubles dans la clause SELECT
def remove_spaces_after_quotes(sql_content):
    match = re.search(r'SELECT(.*?)FROM', sql_content, re.DOTALL | re.IGNORECASE | re.MULTILINE)
    if match:
        select_clause = match.group(1)
        select_clause = re.sub(r'"(\w+_\d+)"\s+', r'"\1"', select_clause)
        sql_content = re.sub(r'SELECT.*?FROM', f'SELECT{select_clause}\nFROM', sql_content, flags=re.DOTALL | re.IGNORECASE | re.MULTILINE)
    return sql_content

# Ajouter le mot clé AS entre X et Y hormis dans la clause SELECT
def add_as_keyword(sql_content):
    sql_content = re.sub(r'(ERMI01\.\w+)\s+(CVAR_DOSSIER__\w+)(?!(.*FROM.*SELECT.*))', r'\1 AS \2', sql_content, flags=re.DOTALL | re.IGNORECASE | re.MULTILINE)
    return sql_content

# Supprimer les doubles quotes
def remove_double_quotes(sql_content):
    sql_content = sql_content.replace('"', '')
    return sql_content

# Exécution des étapes
formatted_sql = format_sql_query(sql_v8_file_raw)
sql_content = remove_aliases(formatted_sql)
sql_content = remove_spaces_after_quotes(sql_content)
sql_content = add_as_keyword(sql_content)
sql_content = remove_double_quotes(sql_content)

# Enregistrement du résultat
with open(sql_v8_file, 'w') as fichier:
    fichier.write(sql_content)

# %% [markdown]
# ### Analyser la Requête - Avec prise en compte des éléments parasites "Tableau des Charges"

# %%
sql_v8_file = r".\data\SQLQuery_ParcWagonV8.sql"

# %%
# Fichier de sortie (résultats) de la requête SQL v8
Result_SQLQueryV8= r".\data\Result_SQLQueryV8.csv"

# %%
# Elemennts de connexion à la Base de Données SQL de Production ; ERMI01
server_prod="frx3sql01.ms.ermi.systems\\ERSX3"
user_prod=None
password_prod=None
db_prod="ersx3"
schema_prod="ERMI01"
driver = "ODBC Driver 17 for SQL Server"

# %%
connection_string = f'DRIVER={driver};SERVER={server_prod};PORT=1433;DATABASE={db_prod};SCHEMA={schema_prod};Trusted_Connection=yes;&autocommit=true'
print(connection_string)
# Out:
# DRIVER=ODBC Driver 17 for SQL Server;SERVER=frx3sql01.ms.ermi.systems\ERSX3;PORT=1433;DATABASE=ersx3;SCHEMA=ERMI01;Trusted_Connection=yes;&autocommit=true

# %%
conn = pyodbc.connect(connection_string)
cursor = conn.cursor()

# %%
# Lire la requête SQL à partir du fichier
with open(sql_v8_file, 'r') as f:
    query = f.read()

# Exécuter la requête SQL
cursor.execute(query)

# Récupérer les résultats
results = cursor.fetchall()

# %%
# Ouvrir le fichier CSV en mode écriture
with open(Result_SQLQueryV8, 'w', newline='',encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)

    # Écrire les en-têtes de colonne
    writer.writerow([desc[0] for desc in cursor.description])

    # Écrire les lignes de résultats
    writer.writerows(results)

# %%
# Fermer curseur et connexion
cursor.close()
conn.close()

# %%
# Créer un dataframe des résultats de la requête SQL v8
# Ici nous avons en colonnes les champs de sortie du modèle
df_result_sqlv8 = pd.read_csv(Result_SQLQueryV8, encoding="utf-8", low_memory=False)

# %%
df_result_sqlv8.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104605 entries, 0 to 104604
# Data columns (total 239 columns):
#  #    Column         Dtype
# ---   ------         -----
#  0    SERNUM_0       int64
#  1    MACNUM_0       int64
#  2    YSA01_0        int64
#  3    YTA03_0        object
#  4    MACTYP_0       object
#  5    YSA04_0        object
#  6    YSA09_0        object
#  7    YTA08_0        object
#  8    YSG04_0        object
#  9    YSG05_0        object
#  10   YSG06_0        object
#  11   YSG07_0        object
#  12   YSG08_0        object
#  13   YSG17_0        object
#  14   YTA02_0        object
#  15   YSG01_0        object
#  16   YSG02_0        object
#  17   YTA05_0        object
#  18   ZCATGEST_0     object
#  19   ZCATCOMM_0     object
#  20   YSG28_0        object
#  21   YSTATITM_0     object
#  22   YSA41_0        object
#  23   SALFCY_0       object
#  24   YSG33_0        object
#  25   YTL01_0        object
#  26   YTL05_0        object
#  27   ZRSRDFLG_0     int64
#  28   ZRSRDMAJ_0     object
#  29   ZRSRDREM_0     object
#  30   YTA78_0        object
#  31   YTA67A_0       object
#  32   YTA67B_0       object
#  33   YTA62_0        object
#  34   YTA73_0        object
#  35   YTL18_0        object
#  36   YTL14_0        object
#  37   YTB40_0        object
#  38   YTA61_0        object
#  39   YTA74_0        float64
#  40   YTA75_0        float64
#  41   YTA70_0        int64
#  42   YTA71_0        int64
#  43   YTA72_0        int64
#  44   YTA64_0        object
#  45   YTA47_0        object
#  46   YTA48_0        object
#  47   YTA56_0        int64
#  48   YTA10_0        object
#  49   YTA11_0        object
#  50   YCD01_0        object
#  51   YCD02_0        object
#  52   YCD03_0        int64
#  53   YCD04_0        float64
#  54   YCD05_0        float64
#  55   YCD01_1        object
#  56   YCD02_1        object
#  57   YCD03_1        int64
#  58   YCD04_1        float64
#  59   YCD05_1        float64
#  60   YCD01_2        object
#  61   YCD02_2        object
#  62   YCD03_2        int64
#  63   YCD04_2        float64
#  64   YCD05_2        float64
#  65   YCD01_3        object
#  66   YCD02_3        object
#  67   YCD03_3        int64
#  68   YCD04_3        float64
#  69   YCD05_3        float64
#  70   YCD01_4        object
#  71   YCD02_4        object
#  72   YCD03_4        int64
#  73   YCD04_4        float64
#  74   YCD05_4        float64
#  75   YCD01_5        object
#  76   YCD02_5        object
#  77   YCD03_5        int64
#  78   YCD04_5        float64
#  79   YCD05_5        float64
#  80   YCD01_6        object
#  81   YCD02_6        object
#  82   YCD03_6        int64
#  83   YCD04_6        float64
#  84   YCD05_6        float64
#  85   YCD01_7        object
#  86   YCD02_7        object
#  87   YCD03_7        int64
#  88   YCD04_7        float64
#  89   YCD05_7        float64
#  90   YCD01_8        object
#  91   YCD02_8        object
#  92   YCD03_8        int64
#  93   YCD04_8        float64
#  94   YCD05_8        float64
#  95   YCD01_9        object
#  96   YCD02_9        object
#  97   YCD03_9        int64
#  98   YCD04_9        float64
#  99   YCD05_9        float64
#  100  YCD01_10       object
#  101  YCD02_10       object
#  102  YCD03_10       int64
#  103  YCD04_10       float64
#  104  YCD05_10       float64
#  105  YCD01_11       object
#  106  YCD02_11       object
#  107  YCD03_11       int64
#  108  YCD04_11       float64
#  109  YCD05_11       float64
#  110  YCD01_12       object
#  111  YCD02_12       object
#  112  YCD03_12       int64
#  113  YCD04_12       float64
#  114  YCD05_12       float64
#  115  YCD01_13       object
#  116  YCD02_13       object
#  117  YCD03_13       int64
#  118  YCD04_13       float64
#  119  YCD05_13       float64
#  120  YCD01_14       object
#  121  YCD02_14       object
#  122  YCD03_14       int64
#  123  YCD04_14       float64
#  124  YCD05_14       float64
#  125  YCD01_15       object
#  126  YCD02_15       object
#  127  YCD03_15       int64
#  128  YCD04_15       float64
#  129  YCD05_15       float64
#  130  YCD01_16       object
#  131  YCD02_16       object
#  132  YCD03_16       int64
#  133  YCD04_16       float64
#  134  YCD05_16       float64
#  135  YCD01_17       object
#  136  YCD02_17       object
#  137  YCD03_17       int64
#  138  YCD04_17       float64
#  139  YCD05_17       float64
#  140  YCD01_18       object
#  141  YCD02_18       object
#  142  YCD03_18       int64
#  143  YCD04_18       float64
#  144  YCD05_18       float64
#  145  YCD01_19       object
#  146  YCD02_19       object
#  147  YCD03_19       int64
#  148  YCD04_19       float64
#  149  YCD05_19       float64
#  150  YCD01_20       object
#  151  YCD02_20       object
#  152  YCD03_20       int64
#  153  YCD04_20       float64
#  154  YCD05_20       float64
#  155  YCD01_21       object
#  156  YCD02_21       object
#  157  YCD03_21       int64
#  158  YCD04_21       float64
#  159  YCD05_21       float64
#  160  YCD01_22       object
#  161  YCD02_22       object
#  162  YCD03_22       int64
#  163  YCD04_22       float64
#  164  YCD05_22       float64
#  165  YCD01_23       object
#  166  YCD02_23       object
#  167  YCD03_23       int64
#  168  YCD04_23       float64
#  169  YCD05_23       float64
#  170  YCD01_24       object
#  171  YCD02_24       object
#  172  YCD03_24       int64
#  173  YCD04_24       float64
#  174  YCD05_24       float64
#  175  YCD01_25       object
#  176  YCD02_25       object
#  177  YCD03_25       int64
#  178  YCD04_25       float64
#  179  YCD05_25       float64
#  180  YCD01_26       object
#  181  YCD02_26       object
#  182  YCD03_26       int64
#  183  YCD04_26       float64
#  184  YCD05_26       float64
#  185  YCD01_27       object
#  186  YCD02_27       object
#  187  YCD03_27       int64
#  188  YCD04_27       float64
#  189  YCD05_27       float64
#  190  YCD01_28       object
#  191  YCD02_28       object
#  192  YCD03_28       int64
#  193  YCD04_28       float64
#  194  YCD05_28       float64
#  195  YCD01_29       object
#  196  YCD02_29       object
#  197  YCD03_29       int64
#  198  YCD04_29       float64
#  199  YCD05_29       float64
#  200  YCHR1_0        object
#  201  YCHA1_0        object
#  202  YCHA1_1        object
#  203  YCHA1_2        object
#  204  YCHA1_3        object
#  205  YCHA1_4        object
#  206  YCHA1_5        object
#  207  YCHA1_6        object
#  208  YCHA1_7        object
#  209  YCHA1_8        object
#  210  YCHA1_9        object
#  211  YCHA1_10       object
#  212  YCHR2_0        object
#  213  YCHA2_0        object
#  214  YCHA2_1        object
#  215  YCHA2_2        object
#  216  YCHA2_3        object
#  217  YCHA2_4        object
#  218  YCHA2_5        object
#  219  YCHA2_6        object
#  220  YCHA2_7        object
#  221  YCHA2_8        object
#  222  YCHA2_9        object
#  223  YCHA2_10       object
#  224  YTA16I_0       float64
#  225  YTA45_0        int64
#  226  YTA42_0        int64
#  227  YTA43_0        int64
#  228  YTA55_0        int64
#  229  YTA44_0        int64
#  230  YTL15_0        object
#  231  XAIO_0         object
#  232  YDATNEXTREV_0  object
#  233  YPLNMCE_0      object
#  234  YMPLIB_0       object
#  235  XPMA_0         float64
#  236  XLOG_0         object
#  237  YBPCUSR_0      object
#  238  YCONREV_0      object
# dtypes: float64(64), int64(43), object(132)
# memory usage: 190.7+ MB

# %%
print(f"En prenant en compte 'Tableau des Charges' il y a ici {df_result_sqlv8.shape[1]} champs de sortie du modèle")
print('\n')
print(f"En prenant en compte 'Tableau des Charges' il y a ici {df_result_sqlv8.shape[0]} enregistrements (lignes) en sortie de modèle")
# Out:
# En prenant en compte 'Tableau des Charges' il y a ici 239 champs de sortie du modèle
#
#
# En prenant en compte 'Tableau des Charges' il y a ici 104605 enregistrements (lignes) en sortie de modèle

# %% [markdown]
# ### Analyser la Requête - Sans prise en compte des éléments parasites "Tableau des Charges"

# %% [markdown]
# Il faut faire abstraction (supprimer) la table "YTECSPE5" des résultats de l'analyse des tables et champs dans toutes les clauses de la requête SQL v8.

# %%
import sqlglot

def get_tables_and_columns(query_file_path):
    tables = []
    
    # Lire la requête SQL depuis le fichier
    with open(query_file_path, 'r') as file:
        query = file.read()

    # Trouver toutes les tables et colonnes dans la requête
    table_column_pattern = re.compile(r'(\w+)\.(\w+)')
    matches = table_column_pattern.findall(query)

    for table, column in matches:
        tables.append({'table': table, 'champ': column})

    return tables

# %%
# Créer les DataFrames
tables = get_tables_and_columns(sql_v8_file)

# Créer le DataFrame pour les tables et colonnes
df_table = pd.DataFrame(tables)

# Trier le DataFrame selon les colonnes 'table' et 'champ'
df_table.sort_values(by=['table','champ'],inplace=True)

# Créer une copie pour df_table_unique
df_table_unique = df_table.copy(deep=True)

# Supprimer les lignes dont les valeurs contiennent "YTECSPE5" dans la colonne "table"
df_table = df_table[(~df_table['table'].str.contains('YTECSPE5')) & (~df_table['table'].str.contains(schema_prod))]

# Dédoublonner le DataFrame afin de ne voir qu'une occurrence de "table" - "champ"
df_table= df_table.drop_duplicates(subset=['table', 'champ']).reset_index(drop=True)

# %%
df_table_unique = df_table_unique[(df_table_unique["table"]==schema_prod) & (~df_table_unique['champ'].str.contains('YTECSPE5'))]
df_table_unique.rename(columns={"table":"env", "champ":"table"},inplace=True)

# %%
df_table_unique
# Out:
#         env      table
# 240  ERMI01  MACHINEFL
# 239  ERMI01   MACHINES
# 249  ERMI01  YMAINPLAN
# 246  ERMI01   YPARCWAG
# 243  ERMI01   YTECSPE1

# %%
print(f"Sans prendre en compte 'Tableau des Charges'\nil y a {df_table_unique.shape[0]} tables uniques impliquées\nSoit un minimum de {df_table_unique.shape[0]-1} champs pour les jointures")
# Out:
# Sans prendre en compte 'Tableau des Charges'
# il y a 5 tables uniques impliquées
# Soit un minimum de 4 champs pour les jointures

# %%
df_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   table   67 non-null     object
#  1   champ   67 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
df_table[df_table["table"].str.contains('YTECSPE5')]
# Out:
# Empty DataFrame
# Columns: [table, champ]
# Index: []

# %%
print(f"Sans prendre en compte 'Tableau des Charges'\nil y a {df_table.shape[0]} champs utilisés\n  En otant les {df_table_unique.shape[0]-1} champs pour les jointures\n  il y a {df_table.shape[0]-(df_table_unique.shape[0]-1)} champs de sortie dans le modèle")
# Out:
# Sans prendre en compte 'Tableau des Charges'
# il y a 67 champs utilisés
#   En otant les 4 champs pour les jointures
#   il y a 63 champs de sortie dans le modèle

# %%
df_table.head(18)
# Out:
#                       table      champ
# 0   CVAR_DOSSIER__MACHINEFL   MACNUM_0
# 1   CVAR_DOSSIER__MACHINEFL   MACTYP_0
# 2   CVAR_DOSSIER__MACHINEFL   SERNUM_0
# 3   CVAR_DOSSIER__MACHINEFL  YPLNMCE_0
# 4   CVAR_DOSSIER__MACHINEFL    YSA01_0
# 5   CVAR_DOSSIER__MACHINEFL    YSA04_0
# 6   CVAR_DOSSIER__MACHINEFL    YSA09_0
# 7   CVAR_DOSSIER__MACHINEFL    YSA41_0
# 8   CVAR_DOSSIER__MACHINEFL    YSG01_0
# 9   CVAR_DOSSIER__MACHINEFL    YSG02_0
# 10  CVAR_DOSSIER__MACHINEFL    YSG04_0
# 11  CVAR_DOSSIER__MACHINEFL    YSG05_0
# 12  CVAR_DOSSIER__MACHINEFL    YSG06_0
# 13  CVAR_DOSSIER__MACHINEFL    YSG07_0
# 14  CVAR_DOSSIER__MACHINEFL    YSG08_0
# 15  CVAR_DOSSIER__MACHINEFL    YSG17_0
# 16  CVAR_DOSSIER__MACHINEFL    YSG33_0
# 17  CVAR_DOSSIER__MACHINEFL    YTA02_0

# %%
# Création de la nouvelle colonne "new_c" en extrayant le groupe à droite du dernier underscore
df_table['table_v8'] = df_table['table'].str.extract('CVAR_DOSSIER__(.*)$')
df_table['champ_v8'] = df_table['champ'].str.removesuffix('_0')
df_table["tablechamp_v8"]=(df_table["table_v8"]+"."+df_table["champ_v8"])
df_table = df_table[["table","champ","table_v8","champ_v8","tablechamp_v8"]]

# %%
df_table
# Out:
#                       table          champ   table_v8     champ_v8         tablechamp_v8
# 0   CVAR_DOSSIER__MACHINEFL       MACNUM_0  MACHINEFL       MACNUM      MACHINEFL.MACNUM
# 1   CVAR_DOSSIER__MACHINEFL       MACTYP_0  MACHINEFL       MACTYP      MACHINEFL.MACTYP
# 2   CVAR_DOSSIER__MACHINEFL       SERNUM_0  MACHINEFL       SERNUM      MACHINEFL.SERNUM
# 3   CVAR_DOSSIER__MACHINEFL      YPLNMCE_0  MACHINEFL      YPLNMCE     MACHINEFL.YPLNMCE
# 4   CVAR_DOSSIER__MACHINEFL        YSA01_0  MACHINEFL        YSA01       MACHINEFL.YSA01
# 5   CVAR_DOSSIER__MACHINEFL        YSA04_0  MACHINEFL        YSA04       MACHINEFL.YSA04
# 6   CVAR_DOSSIER__MACHINEFL        YSA09_0  MACHINEFL        YSA09       MACHINEFL.YSA09
# 7   CVAR_DOSSIER__MACHINEFL        YSA41_0  MACHINEFL        YSA41       MACHINEFL.YSA41
# 8   CVAR_DOSSIER__MACHINEFL        YSG01_0  MACHINEFL        YSG01       MACHINEFL.YSG01
# 9   CVAR_DOSSIER__MACHINEFL        YSG02_0  MACHINEFL        YSG02       MACHINEFL.YSG02
# 10  CVAR_DOSSIER__MACHINEFL        YSG04_0  MACHINEFL        YSG04       MACHINEFL.YSG04
# 11  CVAR_DOSSIER__MACHINEFL        YSG05_0  MACHINEFL        YSG05       MACHINEFL.YSG05
# 12  CVAR_DOSSIER__MACHINEFL        YSG06_0  MACHINEFL        YSG06       MACHINEFL.YSG06
# 13  CVAR_DOSSIER__MACHINEFL        YSG07_0  MACHINEFL        YSG07       MACHINEFL.YSG07
# 14  CVAR_DOSSIER__MACHINEFL        YSG08_0  MACHINEFL        YSG08       MACHINEFL.YSG08
# 15  CVAR_DOSSIER__MACHINEFL        YSG17_0  MACHINEFL        YSG17       MACHINEFL.YSG17
# 16  CVAR_DOSSIER__MACHINEFL        YSG33_0  MACHINEFL        YSG33       MACHINEFL.YSG33
# 17  CVAR_DOSSIER__MACHINEFL        YTA02_0  MACHINEFL        YTA02       MACHINEFL.YTA02
# 18  CVAR_DOSSIER__MACHINEFL        YTA03_0  MACHINEFL        YTA03       MACHINEFL.YTA03
# 19  CVAR_DOSSIER__MACHINEFL        YTA05_0  MACHINEFL        YTA05       MACHINEFL.YTA05
# 20  CVAR_DOSSIER__MACHINEFL        YTA08_0  MACHINEFL        YTA08       MACHINEFL.YTA08
# 21  CVAR_DOSSIER__MACHINEFL     ZCATCOMM_0  MACHINEFL     ZCATCOMM    MACHINEFL.ZCATCOMM
# 22  CVAR_DOSSIER__MACHINEFL     ZCATGEST_0  MACHINEFL     ZCATGEST    MACHINEFL.ZCATGEST
# 23  CVAR_DOSSIER__MACHINEFL     ZRSRDFLG_0  MACHINEFL     ZRSRDFLG    MACHINEFL.ZRSRDFLG
# 24  CVAR_DOSSIER__MACHINEFL     ZRSRDMAJ_0  MACHINEFL     ZRSRDMAJ    MACHINEFL.ZRSRDMAJ
# 25  CVAR_DOSSIER__MACHINEFL     ZRSRDREM_0  MACHINEFL     ZRSRDREM    MACHINEFL.ZRSRDREM
# 26   CVAR_DOSSIER__MACHINES       MACNUM_0   MACHINES       MACNUM       MACHINES.MACNUM
# 27   CVAR_DOSSIER__MACHINES       SALFCY_0   MACHINES       SALFCY       MACHINES.SALFCY
# 28  CVAR_DOSSIER__YMAINPLAN       YMPLIB_0  YMAINPLAN       YMPLIB      YMAINPLAN.YMPLIB
# 29  CVAR_DOSSIER__YMAINPLAN       YMPNUM_0  YMAINPLAN       YMPNUM      YMAINPLAN.YMPNUM
# 30   CVAR_DOSSIER__YPARCWAG       SERNUM_0   YPARCWAG       SERNUM       YPARCWAG.SERNUM
# 31   CVAR_DOSSIER__YPARCWAG         XLOG_0   YPARCWAG         XLOG         YPARCWAG.XLOG
# 32   CVAR_DOSSIER__YPARCWAG         XPMA_0   YPARCWAG         XPMA         YPARCWAG.XPMA
# 33   CVAR_DOSSIER__YPARCWAG      YBPCUSR_0   YPARCWAG      YBPCUSR      YPARCWAG.YBPCUSR
# 34   CVAR_DOSSIER__YPARCWAG      YCONREV_0   YPARCWAG      YCONREV      YPARCWAG.YCONREV
# 35   CVAR_DOSSIER__YPARCWAG  YDATNEXTREV_0   YPARCWAG  YDATNEXTREV  YPARCWAG.YDATNEXTREV
# 36   CVAR_DOSSIER__YPARCWAG        YSG28_0   YPARCWAG        YSG28        YPARCWAG.YSG28
# 37   CVAR_DOSSIER__YPARCWAG     YSTATITM_0   YPARCWAG     YSTATITM     YPARCWAG.YSTATITM
# 38   CVAR_DOSSIER__YTECSPE1       SERNUM_0   YTECSPE1       SERNUM       YTECSPE1.SERNUM
# 39   CVAR_DOSSIER__YTECSPE1         XAIO_0   YTECSPE1         XAIO         YTECSPE1.XAIO
# 40   CVAR_DOSSIER__YTECSPE1       YTA16I_0   YTECSPE1       YTA16I       YTECSPE1.YTA16I
# 41   CVAR_DOSSIER__YTECSPE1        YTA42_0   YTECSPE1        YTA42        YTECSPE1.YTA42
# 42   CVAR_DOSSIER__YTECSPE1        YTA43_0   YTECSPE1        YTA43        YTECSPE1.YTA43
# 43   CVAR_DOSSIER__YTECSPE1        YTA44_0   YTECSPE1        YTA44        YTECSPE1.YTA44
# 44   CVAR_DOSSIER__YTECSPE1        YTA45_0   YTECSPE1        YTA45        YTECSPE1.YTA45
# 45   CVAR_DOSSIER__YTECSPE1        YTA47_0   YTECSPE1        YTA47        YTECSPE1.YTA47
# 46   CVAR_DOSSIER__YTECSPE1        YTA48_0   YTECSPE1        YTA48        YTECSPE1.YTA48
# 47   CVAR_DOSSIER__YTECSPE1        YTA55_0   YTECSPE1        YTA55        YTECSPE1.YTA55
# 48   CVAR_DOSSIER__YTECSPE1        YTA56_0   YTECSPE1        YTA56        YTECSPE1.YTA56
# 49   CVAR_DOSSIER__YTECSPE1        YTA61_0   YTECSPE1        YTA61        YTECSPE1.YTA61
# 50   CVAR_DOSSIER__YTECSPE1        YTA62_0   YTECSPE1        YTA62        YTECSPE1.YTA62
# 51   CVAR_DOSSIER__YTECSPE1        YTA64_0   YTECSPE1        YTA64        YTECSPE1.YTA64
# 52   CVAR_DOSSIER__YTECSPE1       YTA67A_0   YTECSPE1       YTA67A       YTECSPE1.YTA67A
# 53   CVAR_DOSSIER__YTECSPE1       YTA67B_0   YTECSPE1       YTA67B       YTECSPE1.YTA67B
# 54   CVAR_DOSSIER__YTECSPE1        YTA70_0   YTECSPE1        YTA70        YTECSPE1.YTA70
# 55   CVAR_DOSSIER__YTECSPE1        YTA71_0   YTECSPE1        YTA71        YTECSPE1.YTA71
# 56   CVAR_DOSSIER__YTECSPE1        YTA72_0   YTECSPE1        YTA72        YTECSPE1.YTA72
# 57   CVAR_DOSSIER__YTECSPE1        YTA73_0   YTECSPE1        YTA73        YTECSPE1.YTA73
# 58   CVAR_DOSSIER__YTECSPE1        YTA74_0   YTECSPE1        YTA74        YTECSPE1.YTA74
# 59   CVAR_DOSSIER__YTECSPE1        YTA75_0   YTECSPE1        YTA75        YTECSPE1.YTA75
# 60   CVAR_DOSSIER__YTECSPE1        YTA78_0   YTECSPE1        YTA78        YTECSPE1.YTA78
# 61   CVAR_DOSSIER__YTECSPE1        YTB40_0   YTECSPE1        YTB40        YTECSPE1.YTB40
# 62   CVAR_DOSSIER__YTECSPE1        YTL01_0   YTECSPE1        YTL01        YTECSPE1.YTL01
# 63   CVAR_DOSSIER__YTECSPE1        YTL05_0   YTECSPE1        YTL05        YTECSPE1.YTL05
# 64   CVAR_DOSSIER__YTECSPE1        YTL14_0   YTECSPE1        YTL14        YTECSPE1.YTL14
# 65   CVAR_DOSSIER__YTECSPE1        YTL15_0   YTECSPE1        YTL15        YTECSPE1.YTL15
# 66   CVAR_DOSSIER__YTECSPE1        YTL18_0   YTECSPE1        YTL18        YTECSPE1.YTL18

# %%
# Fusionner (merge) du dataframe provenant de l'EOM et du dataframe provenant de la requête SQL v8
df_table_m = pd.merge(
    left=df_table,
    right=df_eom,
    on="tablechamp_v8",
    how="outer",
    indicator=True
    )
df_table_m.drop(columns=["table","champ","table_v8_y","champ_v8_y"],inplace=True)
df_table_m = df_table_m[["designation_champ_sortie","tablechamp_v8","table_v8_x","champ_v8_x","tablechamp_v12","table_v12","champ_v12","_merge"]]
df_table_m.rename(columns={"table_v8_x":"table_v8", "champ_v8_x":"champ_v8"},inplace=True)
df_table_m
# Out:
#                     designation_champ_sortie         tablechamp_v8   table_v8     champ_v8           tablechamp_v12     table_v12    champ_v12     _merge
# 0                           Wag_Code Machine      MACHINEFL.MACNUM  MACHINEFL       MACNUM      XRMWMACPAR00.MACNUM  XRMWMACPAR00       MACNUM       both
# 1                Wag_Code Catégorie de wagon      MACHINEFL.MACTYP  MACHINEFL       MACTYP      XRMWMACPAR00.MACTYP  XRMWMACPAR00       MACTYP       both
# 2                                N° de série      MACHINEFL.SERNUM  MACHINEFL       SERNUM      XRMWMACPAR00.SERNUM  XRMWMACPAR00       SERNUM       both
# 3                        N° Plan maintenance     MACHINEFL.YPLNMCE  MACHINEFL      YPLNMCE           XRMWMPL.YMPNUM       XRMWMPL       YMPNUM       both
# 4                     Wag_N° Immatriculation       MACHINEFL.YSA01  MACHINEFL        YSA01       XRMWMACIMM00.YHI00  XRMWMACIMM00        YHI00       both
# 5                      Wag_Pool mat (gérant)       MACHINEFL.YSA04  MACHINEFL        YSA04       XRMWMACPAR01.YSA04  XRMWMACPAR01        YSA04       both
# 6                       Wag_Etat du matériel       MACHINEFL.YSA09  MACHINEFL        YSA09       XRMWMACPAR01.YSA09  XRMWMACPAR01        YSA09       both
# 7                       Wag_Code Pool Essieu       MACHINEFL.YSA41  MACHINEFL        YSA41       XRMWMACPAR01.YSA41  XRMWMACPAR01        YSA41       both
# 8                 Wag_Date d'entrée sur parc       MACHINEFL.YSG01  MACHINEFL        YSG01       XRMWMACPAR01.YSG01  XRMWMACPAR01        YSG01       both
# 9                Wag_Date désimmatriculation       MACHINEFL.YSG02  MACHINEFL        YSG02       XRMWMACPAR01.YSG02  XRMWMACPAR01        YSG02       both
# 10                            Wag_Mandataire       MACHINEFL.YSG04  MACHINEFL        YSG04       XRMWMACPAR01.YSG04  XRMWMACPAR01        YSG04       both
# 11                          Wag_Gestionnaire       MACHINEFL.YSG05  MACHINEFL        YSG05       XRMWMACPAR01.YSG05  XRMWMACPAR01        YSG05       both
# 12                    Wag_Détenteur immatric       MACHINEFL.YSG06  MACHINEFL        YSG06       XRMWMACPAR01.YSG06  XRMWMACPAR01        YSG06       both
# 13             Wag_Code Exploitant technique       MACHINEFL.YSG07  MACHINEFL        YSG07       XRMWMACPAR01.YSG07  XRMWMACPAR01        YSG07       both
# 14            Wag_Code Exploitant commercial       MACHINEFL.YSG08  MACHINEFL        YSG08       XRMWMACPAR01.YSG08  XRMWMACPAR01        YSG08       both
# 15          Wag_Suivi investissement (CAPEX)       MACHINEFL.YSG17  MACHINEFL        YSG17       XRMWMACPAR01.YSG17  XRMWMACPAR01        YSG17       both
# 16                                   Wag_ECM       MACHINEFL.YSG33  MACHINEFL        YSG33       XRMWMACPAR01.YSG33  XRMWMACPAR01        YSG33       both
# 17                      Wag_Ref Construction       MACHINEFL.YTA02  MACHINEFL        YTA02       XRMWMACPAR01.YTA02  XRMWMACPAR01        YTA02       both
# 18                    Wag_Code Type de Wagon       MACHINEFL.YTA03  MACHINEFL        YTA03       XRMWMACPAR01.YTA03  XRMWMACPAR01        YTA03       both
# 19                        Date 1ère immatric       MACHINEFL.YTA05  MACHINEFL        YTA05       XRMWMACPAR01.YTA05  XRMWMACPAR01        YTA05       both
# 20                     Wag_Code Constructeur       MACHINEFL.YTA08  MACHINEFL        YTA08       XRMWMACPAR01.YTA08  XRMWMACPAR01        YTA08       both
# 21                     Wag_Catég Commerciale    MACHINEFL.ZCATCOMM  MACHINEFL     ZCATCOMM     XRMWMACPAR02.CATCOMM  XRMWMACPAR02      CATCOMM       both
# 22                         Wag_Catég gestion    MACHINEFL.ZCATGEST  MACHINEFL     ZCATGEST     XRMWMACPAR02.CATGEST  XRMWMACPAR02      CATGEST       both
# 23                        Wag_Code Flag RSRD    MACHINEFL.ZRSRDFLG  MACHINEFL     ZRSRDFLG    XRMWMACPAR03.ZRSRDFLG  XRMWMACPAR03     ZRSRDFLG       both
# 24                      Wag_Mise à jour RSRD    MACHINEFL.ZRSRDMAJ  MACHINEFL     ZRSRDMAJ    XRMWMACPAR03.ZRSRDMAJ  XRMWMACPAR03     ZRSRDMAJ       both
# 25                      Wag_Commentaire RSRD    MACHINEFL.ZRSRDREM  MACHINEFL     ZRSRDREM    XRMWMACPAR03.ZRSRDREM  XRMWMACPAR03     ZRSRDREM       both
# 26                                       NaN       MACHINES.MACNUM   MACHINES       MACNUM                      NaN           NaN          NaN  left_only
# 27                            Wag_PC Origine       MACHINES.SALFCY   MACHINES       SALFCY      XRMWMACPAR00.SALFCY  XRMWMACPAR00       SALFCY       both
# 28               Libellé Plan de maintenance      YMAINPLAN.YMPLIB  YMAINPLAN       YMPLIB           XRMWMPL.YMPLIB       XRMWMPL       YMPLIB       both
# 29                                       NaN      YMAINPLAN.YMPNUM  YMAINPLAN       YMPNUM                      NaN           NaN          NaN  left_only
# 30                                       NaN       YPARCWAG.SERNUM   YPARCWAG       SERNUM                      NaN           NaN          NaN  left_only
# 31                       Wag_code retour PMA         YPARCWAG.XLOG   YPARCWAG         XLOG        XRMWMACMIL01.XLOG  XRMWMACMIL01         XLOG       both
# 32                 Wag_Parcours moyen annuel         YPARCWAG.XPMA   YPARCWAG         XPMA        XRMWMACMIL01.XPMA  XRMWMACMIL01         XPMA       both
# 33               Wag_Code client utilisateur      YPARCWAG.YBPCUSR   YPARCWAG      YBPCUSR        XRMWCONMAC.BPCUSR    XRMWCONMAC       BPCUSR       both
# 34                       Wag_contrat avenant      YPARCWAG.YCONREV   YPARCWAG      YCONREV        XRMWCONMAC.CONREV    XRMWCONMAC       CONREV       both
# 35        Wag_Prochaine opération périodique  YPARCWAG.YDATNEXTREV   YPARCWAG  YDATNEXTREV  WXRMWPRGDAT.DATENEXTREV   WXRMWPRGDAT  DATENEXTREV       both
# 36                       Wag_Etat commercial        YPARCWAG.YSG28   YPARCWAG        YSG28       WXRMWMACXON0.YSG28  WXRMWMACXON0        YSG28       both
# 37                           Wag_Code Statut     YPARCWAG.YSTATITM   YPARCWAG     YSTATITM     XRMWMACPAR04.STATITM  XRMWMACPAR04      STATITM       both
# 38                                       NaN       YTECSPE1.SERNUM   YTECSPE1       SERNUM                      NaN           NaN          NaN  left_only
# 39         Wag_Aptitude à l'interopérabilité         YTECSPE1.XAIO   YTECSPE1         XAIO          XRMW1TSP01.XAIO    XRMW1TSP01         XAIO       both
# 40                                  Wag_Tare       YTECSPE1.YTA16I   YTECSPE1       YTA16I         XRMW1TSP01.YTA16    XRMW1TSP01        YTA16       both
# 41                    Wag_Longueur hors tout        YTECSPE1.YTA42   YTECSPE1        YTA42         XRMW1TSP01.YTA42    XRMW1TSP01        YTA42       both
# 42                    Wag_Longueur de pesage        YTECSPE1.YTA43   YTECSPE1        YTA43         XRMW1TSP01.YTA43    XRMW1TSP01        YTA43       both
# 43                   Wag_Empattement châssis        YTECSPE1.YTA44   YTECSPE1        YTA44         XRMW1TSP01.YTA44    XRMW1TSP01        YTA44       both
# 44                    Wag_Inscription courbe        YTECSPE1.YTA45   YTECSPE1        YTA45         XRMW1TSP01.YTA45    XRMW1TSP01        YTA45       both
# 45                    Wag_Code Type de bogie        YTECSPE1.YTA47   YTECSPE1        YTA47         XRMW1TSP03.YTA47    XRMW1TSP03        YTA47       both
# 46                       Wag_Code Suspension        YTECSPE1.YTA48   YTECSPE1        YTA48         XRMW1TSP08.YTA48    XRMW1TSP08        YTA48       both
# 47                     Wag_Décal axe citerne        YTECSPE1.YTA55   YTECSPE1        YTA55         XRMW1TSP02.YTA55    XRMW1TSP02        YTA55       both
# 48                     Wag_Empattement bogie        YTECSPE1.YTA56   YTECSPE1        YTA56             YATABDIV.NO1      YATABDIV          NO1       both
# 49             Wag_Code Type de frein à main        YTECSPE1.YTA61   YTECSPE1        YTA61         XRMW1TSP02.YTA61    XRMW1TSP02        YTA61       both
# 50             Wag_Code Type de distributeur        YTECSPE1.YTA62   YTECSPE1        YTA62         XRMW1TSP02.YTA62    XRMW1TSP02        YTA62       both
# 51                      Wag_Code Vide charge        YTECSPE1.YTA64   YTECSPE1        YTA64         XRMW1TSP02.YTA64    XRMW1TSP02        YTA64       both
# 52       Wag_Code Configuration des semelles       YTECSPE1.YTA67A   YTECSPE1       YTA67A        XRMW1TSP02.YTA67A    XRMW1TSP02       YTA67A       both
# 53                 Wag_Code Type de semelle        YTECSPE1.YTA67B   YTECSPE1       YTA67B        XRMW1TSP02.YTA67B    XRMW1TSP02       YTA67B       both
# 54                  Wag_Masse freinée à vide        YTECSPE1.YTA70   YTECSPE1        YTA70         XRMW1TSP02.YTA70    XRMW1TSP02        YTA70       both
# 55               Wag_Masse freinée en charge        YTECSPE1.YTA71   YTECSPE1        YTA71         XRMW1TSP02.YTA71    XRMW1TSP02        YTA71       both
# 56    Wag_Masse freinée changement de régime        YTECSPE1.YTA72   YTECSPE1        YTA72         XRMW1TSP02.YTA72    XRMW1TSP02        YTA72       both
# 57                       Wag_N° Distributeur        YTECSPE1.YTA73   YTECSPE1        YTA73         XRMW1TSP02.YTA73    XRMW1TSP02        YTA73       both
# 58     Wag_Masse freinée du frein à main (t)        YTECSPE1.YTA74   YTECSPE1        YTA74         XRMW1TSP02.YTA74    XRMW1TSP02        YTA74       both
# 59                Wag_Effort de retenue (Kn)        YTECSPE1.YTA75   YTECSPE1        YTA75         XRMW1TSP02.YTA75    XRMW1TSP02        YTA75       both
# 60                      Wag_Code Valve pesée        YTECSPE1.YTA78   YTECSPE1        YTA78         XRMW1TSP02.YTA78    XRMW1TSP02        YTA78       both
# 61            Wag_N° Distributeur secondaire        YTECSPE1.YTB40   YTECSPE1        YTB40         XRMW1TSP02.YTB40    XRMW1TSP02        YTB40       both
# 62                              Wag_Code RID        YTECSPE1.YTL01   YTECSPE1        YTL01         XRMW1TSP01.YTL01    XRMW1TSP01        YTL01       both
# 63                     Wag_Marquage littéral        YTECSPE1.YTL05   YTECSPE1        YTL05         XRMW1TSP01.YTL05    XRMW1TSP01        YTL05       both
# 64  Wag_Code Type de distributeur secondaire        YTECSPE1.YTL14   YTECSPE1        YTL14         XRMW1TSP02.YTL14    XRMW1TSP02        YTL14       both
# 65                               Wag_Gabarit        YTECSPE1.YTL15   YTECSPE1        YTL15         XRMW1TSP01.YTL15    XRMW1TSP01        YTL15       both
# 66            Wag_Date revision distributeur        YTECSPE1.YTL18   YTECSPE1        YTL18         XRMW1TSP02.YTL18    XRMW1TSP02        YTL18       both

# %%
df_champ_absent_v12 = df_table_m[df_table_m["_merge"]=="left_only"]
df_champ_absent_v12
# Out:
#    designation_champ_sortie     tablechamp_v8   table_v8 champ_v8 tablechamp_v12 table_v12 champ_v12     _merge
# 26                      NaN   MACHINES.MACNUM   MACHINES   MACNUM            NaN       NaN       NaN  left_only
# 29                      NaN  YMAINPLAN.YMPNUM  YMAINPLAN   YMPNUM            NaN       NaN       NaN  left_only
# 30                      NaN   YPARCWAG.SERNUM   YPARCWAG   SERNUM            NaN       NaN       NaN  left_only
# 38                      NaN   YTECSPE1.SERNUM   YTECSPE1   SERNUM            NaN       NaN       NaN  left_only

# %% [markdown]
# ## Etat consolidé pour "Requête SQL du modèle V8 - EOM Sage V12"

# %%
df_champ_v8v12 = df_table_m[df_table_m["_merge"]=="both"].reset_index(drop=True)
df_champ_v8v12
# Out:
#                     designation_champ_sortie         tablechamp_v8   table_v8     champ_v8           tablechamp_v12     table_v12    champ_v12 _merge
# 0                           Wag_Code Machine      MACHINEFL.MACNUM  MACHINEFL       MACNUM      XRMWMACPAR00.MACNUM  XRMWMACPAR00       MACNUM   both
# 1                Wag_Code Catégorie de wagon      MACHINEFL.MACTYP  MACHINEFL       MACTYP      XRMWMACPAR00.MACTYP  XRMWMACPAR00       MACTYP   both
# 2                                N° de série      MACHINEFL.SERNUM  MACHINEFL       SERNUM      XRMWMACPAR00.SERNUM  XRMWMACPAR00       SERNUM   both
# 3                        N° Plan maintenance     MACHINEFL.YPLNMCE  MACHINEFL      YPLNMCE           XRMWMPL.YMPNUM       XRMWMPL       YMPNUM   both
# 4                     Wag_N° Immatriculation       MACHINEFL.YSA01  MACHINEFL        YSA01       XRMWMACIMM00.YHI00  XRMWMACIMM00        YHI00   both
# 5                      Wag_Pool mat (gérant)       MACHINEFL.YSA04  MACHINEFL        YSA04       XRMWMACPAR01.YSA04  XRMWMACPAR01        YSA04   both
# 6                       Wag_Etat du matériel       MACHINEFL.YSA09  MACHINEFL        YSA09       XRMWMACPAR01.YSA09  XRMWMACPAR01        YSA09   both
# 7                       Wag_Code Pool Essieu       MACHINEFL.YSA41  MACHINEFL        YSA41       XRMWMACPAR01.YSA41  XRMWMACPAR01        YSA41   both
# 8                 Wag_Date d'entrée sur parc       MACHINEFL.YSG01  MACHINEFL        YSG01       XRMWMACPAR01.YSG01  XRMWMACPAR01        YSG01   both
# 9                Wag_Date désimmatriculation       MACHINEFL.YSG02  MACHINEFL        YSG02       XRMWMACPAR01.YSG02  XRMWMACPAR01        YSG02   both
# 10                            Wag_Mandataire       MACHINEFL.YSG04  MACHINEFL        YSG04       XRMWMACPAR01.YSG04  XRMWMACPAR01        YSG04   both
# 11                          Wag_Gestionnaire       MACHINEFL.YSG05  MACHINEFL        YSG05       XRMWMACPAR01.YSG05  XRMWMACPAR01        YSG05   both
# 12                    Wag_Détenteur immatric       MACHINEFL.YSG06  MACHINEFL        YSG06       XRMWMACPAR01.YSG06  XRMWMACPAR01        YSG06   both
# 13             Wag_Code Exploitant technique       MACHINEFL.YSG07  MACHINEFL        YSG07       XRMWMACPAR01.YSG07  XRMWMACPAR01        YSG07   both
# 14            Wag_Code Exploitant commercial       MACHINEFL.YSG08  MACHINEFL        YSG08       XRMWMACPAR01.YSG08  XRMWMACPAR01        YSG08   both
# 15          Wag_Suivi investissement (CAPEX)       MACHINEFL.YSG17  MACHINEFL        YSG17       XRMWMACPAR01.YSG17  XRMWMACPAR01        YSG17   both
# 16                                   Wag_ECM       MACHINEFL.YSG33  MACHINEFL        YSG33       XRMWMACPAR01.YSG33  XRMWMACPAR01        YSG33   both
# 17                      Wag_Ref Construction       MACHINEFL.YTA02  MACHINEFL        YTA02       XRMWMACPAR01.YTA02  XRMWMACPAR01        YTA02   both
# 18                    Wag_Code Type de Wagon       MACHINEFL.YTA03  MACHINEFL        YTA03       XRMWMACPAR01.YTA03  XRMWMACPAR01        YTA03   both
# 19                        Date 1ère immatric       MACHINEFL.YTA05  MACHINEFL        YTA05       XRMWMACPAR01.YTA05  XRMWMACPAR01        YTA05   both
# 20                     Wag_Code Constructeur       MACHINEFL.YTA08  MACHINEFL        YTA08       XRMWMACPAR01.YTA08  XRMWMACPAR01        YTA08   both
# 21                     Wag_Catég Commerciale    MACHINEFL.ZCATCOMM  MACHINEFL     ZCATCOMM     XRMWMACPAR02.CATCOMM  XRMWMACPAR02      CATCOMM   both
# 22                         Wag_Catég gestion    MACHINEFL.ZCATGEST  MACHINEFL     ZCATGEST     XRMWMACPAR02.CATGEST  XRMWMACPAR02      CATGEST   both
# 23                        Wag_Code Flag RSRD    MACHINEFL.ZRSRDFLG  MACHINEFL     ZRSRDFLG    XRMWMACPAR03.ZRSRDFLG  XRMWMACPAR03     ZRSRDFLG   both
# 24                      Wag_Mise à jour RSRD    MACHINEFL.ZRSRDMAJ  MACHINEFL     ZRSRDMAJ    XRMWMACPAR03.ZRSRDMAJ  XRMWMACPAR03     ZRSRDMAJ   both
# 25                      Wag_Commentaire RSRD    MACHINEFL.ZRSRDREM  MACHINEFL     ZRSRDREM    XRMWMACPAR03.ZRSRDREM  XRMWMACPAR03     ZRSRDREM   both
# 26                            Wag_PC Origine       MACHINES.SALFCY   MACHINES       SALFCY      XRMWMACPAR00.SALFCY  XRMWMACPAR00       SALFCY   both
# 27               Libellé Plan de maintenance      YMAINPLAN.YMPLIB  YMAINPLAN       YMPLIB           XRMWMPL.YMPLIB       XRMWMPL       YMPLIB   both
# 28                       Wag_code retour PMA         YPARCWAG.XLOG   YPARCWAG         XLOG        XRMWMACMIL01.XLOG  XRMWMACMIL01         XLOG   both
# 29                 Wag_Parcours moyen annuel         YPARCWAG.XPMA   YPARCWAG         XPMA        XRMWMACMIL01.XPMA  XRMWMACMIL01         XPMA   both
# 30               Wag_Code client utilisateur      YPARCWAG.YBPCUSR   YPARCWAG      YBPCUSR        XRMWCONMAC.BPCUSR    XRMWCONMAC       BPCUSR   both
# 31                       Wag_contrat avenant      YPARCWAG.YCONREV   YPARCWAG      YCONREV        XRMWCONMAC.CONREV    XRMWCONMAC       CONREV   both
# 32        Wag_Prochaine opération périodique  YPARCWAG.YDATNEXTREV   YPARCWAG  YDATNEXTREV  WXRMWPRGDAT.DATENEXTREV   WXRMWPRGDAT  DATENEXTREV   both
# 33                       Wag_Etat commercial        YPARCWAG.YSG28   YPARCWAG        YSG28       WXRMWMACXON0.YSG28  WXRMWMACXON0        YSG28   both
# 34                           Wag_Code Statut     YPARCWAG.YSTATITM   YPARCWAG     YSTATITM     XRMWMACPAR04.STATITM  XRMWMACPAR04      STATITM   both
# 35         Wag_Aptitude à l'interopérabilité         YTECSPE1.XAIO   YTECSPE1         XAIO          XRMW1TSP01.XAIO    XRMW1TSP01         XAIO   both
# 36                                  Wag_Tare       YTECSPE1.YTA16I   YTECSPE1       YTA16I         XRMW1TSP01.YTA16    XRMW1TSP01        YTA16   both
# 37                    Wag_Longueur hors tout        YTECSPE1.YTA42   YTECSPE1        YTA42         XRMW1TSP01.YTA42    XRMW1TSP01        YTA42   both
# 38                    Wag_Longueur de pesage        YTECSPE1.YTA43   YTECSPE1        YTA43         XRMW1TSP01.YTA43    XRMW1TSP01        YTA43   both
# 39                   Wag_Empattement châssis        YTECSPE1.YTA44   YTECSPE1        YTA44         XRMW1TSP01.YTA44    XRMW1TSP01        YTA44   both
# 40                    Wag_Inscription courbe        YTECSPE1.YTA45   YTECSPE1        YTA45         XRMW1TSP01.YTA45    XRMW1TSP01        YTA45   both
# 41                    Wag_Code Type de bogie        YTECSPE1.YTA47   YTECSPE1        YTA47         XRMW1TSP03.YTA47    XRMW1TSP03        YTA47   both
# 42                       Wag_Code Suspension        YTECSPE1.YTA48   YTECSPE1        YTA48         XRMW1TSP08.YTA48    XRMW1TSP08        YTA48   both
# 43                     Wag_Décal axe citerne        YTECSPE1.YTA55   YTECSPE1        YTA55         XRMW1TSP02.YTA55    XRMW1TSP02        YTA55   both
# 44                     Wag_Empattement bogie        YTECSPE1.YTA56   YTECSPE1        YTA56             YATABDIV.NO1      YATABDIV          NO1   both
# 45             Wag_Code Type de frein à main        YTECSPE1.YTA61   YTECSPE1        YTA61         XRMW1TSP02.YTA61    XRMW1TSP02        YTA61   both
# 46             Wag_Code Type de distributeur        YTECSPE1.YTA62   YTECSPE1        YTA62         XRMW1TSP02.YTA62    XRMW1TSP02        YTA62   both
# 47                      Wag_Code Vide charge        YTECSPE1.YTA64   YTECSPE1        YTA64         XRMW1TSP02.YTA64    XRMW1TSP02        YTA64   both
# 48       Wag_Code Configuration des semelles       YTECSPE1.YTA67A   YTECSPE1       YTA67A        XRMW1TSP02.YTA67A    XRMW1TSP02       YTA67A   both
# 49                 Wag_Code Type de semelle        YTECSPE1.YTA67B   YTECSPE1       YTA67B        XRMW1TSP02.YTA67B    XRMW1TSP02       YTA67B   both
# 50                  Wag_Masse freinée à vide        YTECSPE1.YTA70   YTECSPE1        YTA70         XRMW1TSP02.YTA70    XRMW1TSP02        YTA70   both
# 51               Wag_Masse freinée en charge        YTECSPE1.YTA71   YTECSPE1        YTA71         XRMW1TSP02.YTA71    XRMW1TSP02        YTA71   both
# 52    Wag_Masse freinée changement de régime        YTECSPE1.YTA72   YTECSPE1        YTA72         XRMW1TSP02.YTA72    XRMW1TSP02        YTA72   both
# 53                       Wag_N° Distributeur        YTECSPE1.YTA73   YTECSPE1        YTA73         XRMW1TSP02.YTA73    XRMW1TSP02        YTA73   both
# 54     Wag_Masse freinée du frein à main (t)        YTECSPE1.YTA74   YTECSPE1        YTA74         XRMW1TSP02.YTA74    XRMW1TSP02        YTA74   both
# 55                Wag_Effort de retenue (Kn)        YTECSPE1.YTA75   YTECSPE1        YTA75         XRMW1TSP02.YTA75    XRMW1TSP02        YTA75   both
# 56                      Wag_Code Valve pesée        YTECSPE1.YTA78   YTECSPE1        YTA78         XRMW1TSP02.YTA78    XRMW1TSP02        YTA78   both
# 57            Wag_N° Distributeur secondaire        YTECSPE1.YTB40   YTECSPE1        YTB40         XRMW1TSP02.YTB40    XRMW1TSP02        YTB40   both
# 58                              Wag_Code RID        YTECSPE1.YTL01   YTECSPE1        YTL01         XRMW1TSP01.YTL01    XRMW1TSP01        YTL01   both
# 59                     Wag_Marquage littéral        YTECSPE1.YTL05   YTECSPE1        YTL05         XRMW1TSP01.YTL05    XRMW1TSP01        YTL05   both
# 60  Wag_Code Type de distributeur secondaire        YTECSPE1.YTL14   YTECSPE1        YTL14         XRMW1TSP02.YTL14    XRMW1TSP02        YTL14   both
# 61                               Wag_Gabarit        YTECSPE1.YTL15   YTECSPE1        YTL15         XRMW1TSP01.YTL15    XRMW1TSP01        YTL15   both
# 62            Wag_Date revision distributeur        YTECSPE1.YTL18   YTECSPE1        YTL18         XRMW1TSP02.YTL18    XRMW1TSP02        YTL18   both

# %% [markdown]
# ## Exploiter le fichier MDLX du modèle V8

# %% [markdown]
# ### Créer un JSON du Fichier du modèle V8 - Avec prise en compte des éléments parasites "Tableau des Charges"

# %%
mdlx_v8_file = r".\data\ParcWagonV8.mdlx" # fichier d'entrée
json_v8_file = r".\data\model_v8.json" # fichier de sortie

# %%
import xml.etree.ElementTree as ET
import json

# Charger le fichier MDLX avec encoding UTF-8
tree = ET.parse(mdlx_v8_file, parser=ET.XMLParser(encoding='utf-8'))
root = tree.getroot()

# Fonction récursive pour parser l'arbre XML
def parse_node(node):
    data = {}
    for child in node:
        if len(child) > 0:
            if child.tag in data:
                if not isinstance(data[child.tag], list):
                    data[child.tag] = [data[child.tag]]
                data[child.tag].append(parse_node(child))
            else:
                data[child.tag] = parse_node(child)
        else:
            if child.tag in data:
                if not isinstance(data[child.tag], list):
                    data[child.tag] = [data[child.tag]]
                data[child.tag].append(child.text)
            else:
                data[child.tag] = child.text
        # Ajouter les attributs
        for attr in child.attrib:
            if f"{child.tag}_{attr}" in data:
                if not isinstance(data[f"{child.tag}_{attr}"], list):
                    data[f"{child.tag}_{attr}"] = [data[f"{child.tag}_{attr}"]]
                data[f"{child.tag}_{attr}"].append(child.attrib[attr])
            else:
                data[f"{child.tag}_{attr}"] = child.attrib[attr]
    # Ajouter les attributs du nœud actuel
    for attr in node.attrib:
        if f"{node.tag}_{attr}" in data:
            if not isinstance(data[f"{node.tag}_{attr}"], list):
                data[f"{node.tag}_{attr}"] = [data[f"{node.tag}_{attr}"]]
            data[f"{node.tag}_{attr}"].append(node.attrib[attr])
        else:
            data[f"{node.tag}_{attr}"] = node.attrib[attr]
    return data

# Parser l'arbre XML
data = parse_node(root)

# Créer le fichier JSON avec encoding UTF-8
with open(json_v8_file, 'w', encoding='utf-8') as f:
    json.dump(data, f, indent=4, ensure_ascii=False)

# %% [markdown]
# Lors de l'analyse du fichier XML, nous avons ajouté le paramètre parser à ET.parse() et spécifié une instance XMLParser avec encoding='utf-8'.
# - Cela indique à ElementTree qu'il doit utiliser l'encodage UTF-8 lors de la lecture du fichier XML.
#
# Lors de l'écriture du fichier JSON, nous avons ajouté le paramètre ensure_ascii=False à json.dump().
# - Cela indique au sérialiseur JSON qu'il doit préserver les caractères non ASCII (comme les accents) au lieu de les escamoter.

# %% [markdown]
# ## Exploiter le fichier MDLX du modèle V12

# %% [markdown]
# ### Créer un JSON du Fichier du modèle V12 - Sans prise en compte des éléments parasites "Tableau des Charges"

# %%
mdlx_v12_file = r".\data\ParcWagonV12.mdlx" # fichier d'entrée
json_v12_file = r".\data\model_v12.json" # fichier de sortie

# %%
import xml.etree.ElementTree as ET
import json

# Charger le fichier MDLX avec encoding UTF-8
tree = ET.parse(mdlx_v12_file, parser=ET.XMLParser(encoding='utf-8'))
root = tree.getroot()

# Fonction récursive pour parser l'arbre XML
def parse_node(node):
    data = {}
    for child in node:
        if len(child) > 0:
            if child.tag in data:
                if not isinstance(data[child.tag], list):
                    data[child.tag] = [data[child.tag]]
                data[child.tag].append(parse_node(child))
            else:
                data[child.tag] = parse_node(child)
        else:
            if child.tag in data:
                if not isinstance(data[child.tag], list):
                    data[child.tag] = [data[child.tag]]
                data[child.tag].append(child.text)
            else:
                data[child.tag] = child.text
        # Ajouter les attributs
        for attr in child.attrib:
            if f"{child.tag}_{attr}" in data:
                if not isinstance(data[f"{child.tag}_{attr}"], list):
                    data[f"{child.tag}_{attr}"] = [data[f"{child.tag}_{attr}"]]
                data[f"{child.tag}_{attr}"].append(child.attrib[attr])
            else:
                data[f"{child.tag}_{attr}"] = child.attrib[attr]
    # Ajouter les attributs du nœud actuel
    for attr in node.attrib:
        if f"{node.tag}_{attr}" in data:
            if not isinstance(data[f"{node.tag}_{attr}"], list):
                data[f"{node.tag}_{attr}"] = [data[f"{node.tag}_{attr}"]]
            data[f"{node.tag}_{attr}"].append(node.attrib[attr])
        else:
            data[f"{node.tag}_{attr}"] = node.attrib[attr]
    return data

# Parser l'arbre XML
data = parse_node(root)

# Créer le fichier JSON avec encoding UTF-8
with open(json_v12_file, 'w', encoding='utf-8') as f:
    json.dump(data, f, indent=4, ensure_ascii=False)
